# %% [markdown]
# # AND 게이트 구현
# - 두 개의 입력이 모두 1인 경우에만 출력값이 1, 나머지 경우는 모두 출력값 0
#
# <img src = "https://user-images.githubusercontent.com/119478998/210686693-4f962a37-1409-4dba-8ece-9d4d27ef1f70.png"/>

# %%
def AND_gate(x1, x2):
    w1 = 0.5
    w2 = 0.5
    b = -0.7
    result = x1*w1 + x2*w2 + b
    if result <= 0:
        return 0
    else:
        return 1

# %%
AND_gate(0, 0), AND_gate(0, 1), AND_gate(1, 0), AND_gate(1, 1)

# %% [markdown]
# # NAND 게이트 구현
#
#
# <img src = "https://user-images.githubusercontent.com/119478998/210685471-cc32d25c-8bad-49d1-9911-c02fa28ca02c.png"/>

# %%
def NAND_gate(x1, x2):
    w1 = -0.5
    w2 = -0.5
    b = 0.7
    result = x1*w1 + x2*w2 + b
    if result <= 0:
        return 0
    else:
        return 1

# %%
NAND_gate(0, 0), NAND_gate(0, 1), NAND_gate(1, 0), NAND_gate(1, 1)

# %% [markdown]
# # OR 게이트 구현
# - 두 개의 입력이 모두 0인 경우에 출력값이 0, 나머지 경우는 모두 출력값 1
#
# <img src = "https://user-images.githubusercontent.com/119478998/210685771-3b979082-d113-435f-9dfd-1fbb0382b097.png"/>

# %%
def OR_gate(x1, x2) :
  w1 = 0.6
  w2 = 0.6
  b = -0.5
  result = x1*w1 + x2*w2 + b
  if result <= 0 :
    return 0
  else :
    return 1

# %%
OR_gate(0, 0), OR_gate(0, 1), OR_gate(1, 0), OR_gate(1, 1)
# Out:
# (0, 1, 1, 1)

# %%
# tensorflow를 이용해 구현

import tensorflow as tf
tf.random.set_seed(777)

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import mse

# 데이터 준비
x = np.array([[0,0], [1,0], [0,1], [1,1]])
y = np.array([[0], [1], [1], [1]])

# 모델 구성
model = Sequential()
model.add(Dense(1, input_shape=(2,), activation = "linear")) # 단층 퍼셉트론 구성

# 모델 준비
model.compile(optimizer=SGD(), 
              loss=mse,
              metrics=["acc"]) # list 형태로 평가지표 전달

# 학습
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 1.4290 - acc: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3602 - acc: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2956 - acc: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.2349 - acc: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1779 - acc: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1242 - acc: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0738 - acc: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0264 - acc: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9819 - acc: 0.5000
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9399 - acc: 0.5000
# Epoch 11/500
# ...

# %% [markdown]
# # XOR 게이트 구현
#
# <img src = "https://user-images.githubusercontent.com/119478998/210684258-af89fb83-56f2-478a-acad-62bc9eb0c0c9.png"/>

# %%
# tensorflow를 이용해 구현

import tensorflow as tf
tf.random.set_seed(777)

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import mse

# 데이터 준비
data = np.array([[0,0], [1,0], [0,1], [1,1]])
label = np.array([[0], [1], [1], [0]])

# 모델 구성
model = Sequential()
# 다층 퍼셉트론 구성 : 2개의 Dense층 연결. 항상 모델의 첫번째 층은 데이터 형태(input_shape)를 전달해줘야함
model.add(Dense(32, input_shape = (2,), activation = "relu")) 
model.add(Dense(1, activation="sigmoid"))

# 모델 준비 : 학습 과정 설정
model.compile(optimizer=RMSprop(),
              loss = mse,
              metrics= ["acc"])

# 학습시키기
model.fit(data, label, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 666ms/step - loss: 0.2646 - acc: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2621 - acc: 0.2500
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2603 - acc: 0.2500
# Epoch 4/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2589 - acc: 0.2500
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2578 - acc: 0.2500
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2568 - acc: 0.2500
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2558 - acc: 0.2500
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2550 - acc: 0.2500
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2541 - acc: 0.2500
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2533 - acc: 0.2500
# Epoch 11/100
# ...

# %% [markdown]
# ---

# %% [markdown]
# References
# - [딥러닝을 이용한 자연어 처리 입문](https://wikidocs.net/24958)
# - 백견불여일타 딥러닝 입문 with 텐서플로우 2.x
